# %%
import numpy as np, pandas as pd
df=pd.read_csv('Service_Area_PUF.csv',usecols=['StateCode','StateCode2','PartialCounty','IssuerId2','CoverEntireState'])
df
# Out:
#      StateCode  IssuerId2 StateCode2 CoverEntireState PartialCounty
# 0           PA      22444         PA               No            No
# 1           PA      22444         PA               No            No
# 2           PA      22444         PA               No            No
# 3           PA      22444         PA               No            No
# 4           PA      22444         PA               No            No
# ...        ...        ...        ...              ...           ...
# 8869        VA      88380         VA               No            No
# 8870        VA      88380         VA               No            No
# 8871        VA      88380         VA               No            No
# 8872        VA      88380         VA               No            No
# 8873        VA      88380         VA               No            No
#
# [8874 rows x 5 columns]

# %%
#Get top X  categories in the selected column i.e colName
def getTop_X_cat(X,colName):
  for colName in df.columns:
       if colName in df:
          freq=df[colName].value_counts().sort_values(ascending=False)
          top =[x for x in freq.head(X).index] 
          print(freq)
          return top
top_X=getTop_X_cat(10,'StateCode2')
# print(top_X)

# #Apply one hot encoding for the top X categorical variables in each column
def oneHotEncode_topX(df,colName,top_X):
  for i in top_X:
    df[colName+'_'+i]=np.where(df[colName]==i,1,0)

oneHotEncode_topX(df,"StateCode2",top_X)
  
df.head(10)
# Out:
# VA    1382
# MI    1149
# PA     864
# TX     694
# KS     448
# IL     422
# MO     366
# OH     338
# WI     320
# GA     298
# NE     295
# OK     229
# IA     223
# FL     196
# ID     188
# UT     182
# NC     177
# TN     166
# IN     154
# AR     144
# LA     140
# MS      92
# NJ      77
# ME      64
# AZ      62
# ND      60
# SC      25
# NM      18
# MT      18
# DE      15
# NH      15
# SD      13
# AL      12
# AK      10
# WV      10
# WY       8
# Name: StateCode, dtype: int64
#   StateCode  IssuerId2 StateCode2  ... StateCode2_OH StateCode2_WI  StateCode2_GA
# 0        PA      22444         PA  ...             0             0              0
# 1        PA      22444         PA  ...             0             0              0
# 2        PA      22444         PA  ...             0             0              0
# 3        PA      22444         PA  ...             0             0              0
# ...

# %%
for cat in df.columns:
   print(cat, '::', len(df[cat].unique()),"labels")
pd.get_dummies(df,drop_first=True).shape
# Out:
# StateCode :: 36 labels
# IssuerId2 :: 450 labels
# StateCode2 :: 36 labels
# CoverEntireState :: 2 labels
# PartialCounty :: 3 labels
# (8874, 73)

# %%
#Feature Engineering various techniques for nominal ex: gender and ordinal ex: pincode variables.

#One hot encoding for nominal variables using get_dummies
pd.get_dummies(df,drop_first=True)
# Out:
#       IssuerId2  StateCode2_VA  ...  CoverEntireState_Yes  PartialCounty_Yes
# 0         22444              0  ...                     0                  0
# 1         22444              0  ...                     0                  0
# 2         22444              0  ...                     0                  0
# 3         22444              0  ...                     0                  0
# 4         22444              0  ...                     0                  0
# ...         ...            ...  ...                   ...                ...
# 8869      88380              1  ...                     0                  0
# 8870      88380              1  ...                     0                  0
# 8871      88380              1  ...                     0                  0
# 8872      88380              1  ...                     0                  0
# 8873      88380              1  ...                     0                  0
#
# [8874 rows x 83 columns]
